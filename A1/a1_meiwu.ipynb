# %%
import cowsay
cowsay.tux("meeeerp \n YELLOOWWWW")
# Out:
#   __________
#  /          \
# | meeeerp    |
# | YELLOOWWWW |
#  \          /
# ...
#                \
#                 \
#                  \
#                   .--.
#                  |o_o |
#                  |:_/ |
#                 //   \ \
#                (|     | )
#               /'\_   _/`\
#               \___)=(___/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])
df.plot.area();
